# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Sat Mar  9 09:43:43 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Clone and Install

# %% [markdown]
# **NOTE:** YOLOv9 is very new. At the moment, we recommend using a fork of the main repository. The `detect.py` script contains a bug that prevents inference. This bug is patched in the fork.

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Counting objects: 100% (172/172), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 325 (delta 134), reused 102 (delta 102), pack-reused 153
# Receiving objects: 100% (325/325), 2.26 MiB | 23.65 MiB/s, done.
# Resolving deltas: 100% (159/159), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 13.2 MB/s eta 0:00:00

# %% [markdown]
# **NOTE:** Let's install additional packages that will be useful later on.

# %%
# !pip install -q roboflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 21.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 18.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.2 MB/s eta 0:00:00

# %% [markdown]
# ## Imports

# %%
import roboflow

from IPython.display import Image

# %% [markdown]
# ## Download model weights

# %% [markdown]
# **NOTE:** In the YOLOv9 paper, versions yolov9-s and yolov9-m are also mentioned, but the weights for these models are not yet available in the YOLOv9 repository.

# %%
# !mkdir -p {HOME}/weights

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !ls -la {HOME}/weights
# Out:
# total 402440
# drwxr-xr-x 2 root root      4096 Mar  9 09:45 .
# drwxr-xr-x 1 root root      4096 Mar  9 09:45 ..
# -rw-r--r-- 1 root root  51508261 Feb 18 12:36 gelan-c.pt
# -rw-r--r-- 1 root root 117203713 Feb 18 12:36 gelan-e.pt
# -rw-r--r-- 1 root root 103153312 Feb 18 12:36 yolov9-c.pt
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt

# %% [markdown]
# ## Download example data

# %%
# !mkdir -p {HOME}/data

# %% [markdown]
# ## Detection with pre-trained COCO model

# %% [markdown]
# ### gelan-c

# %%
# !python detect.py --weights {HOME}/weights/gelan-c.pt --conf 0.1 --source /content/yolov9/otoyol.jpg --device 0
# Out:
# detect: weights=['/content/weights/gelan-c.pt'], source=/content/yolov9/otoyol.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 467 layers, 25472640 parameters, 0 gradients, 102.8 GFLOPs
# image 1/1 /content/yolov9/otoyol.jpg: 384x640 14 cars, 1 bus, 1 train, 1 truck, 164.6ms
# Speed: 0.5ms pre-process, 164.6ms inference, 675.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %% [markdown]
# **NOTE:** By default, the results of each subsequent inference sessions are saved in `{HOME}/yolov9/runs/detect/`, in directories named `exp`, `exp2`, `exp3`, ... You can override this behavior by using the `--name` parameter.

# %%
Image(filename=f"{HOME}/yolov9/runs/detect/exp/otoyol.jpg", width=600)

# %% [markdown]
# ## yolov9-e

# %%
# !python detect.py --weights {HOME}/weights/yolov9-e.pt --conf 0.1 --source /content/yolov9/otoyol.jpg --device 0
# Out:
# detect: weights=['/content/weights/yolov9-e.pt'], source=/content/yolov9/otoyol.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 1119 layers, 69470144 parameters, 0 gradients, 244.0 GFLOPs
# image 1/1 /content/yolov9/otoyol.jpg: 384x640 13 cars, 1 bus, 3 trucks, 160.5ms
# Speed: 0.4ms pre-process, 160.5ms inference, 489.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
Image(filename=f"{HOME}/yolov9/runs/detect/exp2/dog.jpeg", width=600)

# %% [markdown]
# ## Authenticate and Download the Dataset

# %% [markdown]
# **NOTE:** The dataset must be saved inside the `{HOME}/yolov9` directory, otherwise, the training will not succeed.

# %%
# %cd {HOME}/yolov9


from roboflow import Roboflow
rf = Roboflow(api_key="zR6CrKGUlZbZTWM55Uad")
project = rf.workspace("joseph-nelson").project("mask-wearing")
dataset = project.version(4).download("yolov8")
# Out:
# /content/yolov9
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# Downloading Dataset Version Zip in Mask-Wearing-4 to yolov8:: 100%|██████████| 19019/19019 [00:00<00:00, 26977.72it/s]
# Extracting Dataset Version Zip to Mask-Wearing-4 in yolov8:: 100%|██████████| 310/310 [00:00<00:00, 2285.07it/s]

# %% [markdown]
# ## Train Custom Model

# %%
# %cd {HOME}/yolov9

# !python train.py \
--batch 8 --epochs 10 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data {dataset.location}/data.yaml \
--weights {HOME}/weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# /content/yolov9
# 2024-03-09 09:58:52.865197: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-09 09:58:52.865245: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-09 09:58:52.866647: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-09 09:58:53.937877: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# train: weights=/content/weights/gelan-c.pt, cfg=models/detect/gelan-c.yaml, data=/content/yolov9/Mask-Wearing-4/data.yaml, hyp=hyp.scratch-high.yaml, epochs=10, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, cls_pw=1.0, dfl=1.5, obj_pw=1.0, iou_t=0.2, anchor_t=5.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLO 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLO 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 17.3MB/s]
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    212864  models.common.RepNCSPELAN4              [128, 256, 128, 64, 1]
#   3                -1  1    164352  models.common.ADown                     [256, 256]
#   4                -1  1    847616  models.common.RepNCSPELAN4              [256, 512, 256, 128, 1]
#   5                -1  1    656384  models.common.ADown                     [512, 512]
#   6                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   7                -1  1    656384  models.common.ADown                     [512, 512]
#   8                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   9                -1  1    656896  models.common.SPPELAN                   [512, 512, 256]
#  10                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  11           [-1, 6]  1         0  models.common.Concat                    [1]
#  12                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 4]  1         0  models.common.Concat                    [1]
#  15                -1  1    912640  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 1]
#  16                -1  1    164352  models.common.ADown                     [256, 256]
#  17          [-1, 12]  1         0  models.common.Concat                    [1]
#  18                -1  1   2988544  models.common.RepNCSPELAN4              [768, 512, 512, 256, 1]
#  19                -1  1    656384  models.common.ADown                     [512, 512]
#  20           [-1, 9]  1         0  models.common.Concat                    [1]
#  21                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  22      [15, 18, 21]  1   5492182  models.yolo.DDetect                     [2, [256, 512, 512]]
# gelan-c summary: 621 layers, 25438614 parameters, 25438598 gradients, 103.2 GFLOPs
#
# Transferred 931/937 items from /content/weights/gelan-c.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 154 weight(decay=0.0), 161 weight(decay=0.0005), 160 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/yolov9/Mask-Wearing-4/train/labels... 105 images, 0 backgrounds, 0 corrupt: 100% 105/105 [00:00<00:00, 1270.15it/s]
# train: New cache created: /content/yolov9/Mask-Wearing-4/train/labels.cache
# val: Scanning /content/yolov9/Mask-Wearing-4/valid/labels... 29 images, 0 backgrounds, 0 corrupt: 100% 29/29 [00:00<00:00, 871.68it/s]
# val: New cache created: /content/yolov9/Mask-Wearing-4/valid/labels.cache
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 10 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         0/9      6.83G       1.96       4.44      1.659          2        640: 100% 14/14 [00:22<00:00,  1.63s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:02<00:00,  1.40s/it]
#                    all         29        162     0.0307     0.0528      0.017    0.00815
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/9      6.83G      1.613       2.26      1.433          3        640: 100% 14/14 [00:10<00:00,  1.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.32it/s]
#                    all         29        162      0.394      0.411      0.378      0.225
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/9      6.83G      1.228      1.446      1.207          8        640: 100% 14/14 [00:09<00:00,  1.40it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.83it/s]
#                    all         29        162      0.518      0.578      0.464      0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/9      6.83G        1.4      1.358      1.261         10        640: 100% 14/14 [00:11<00:00,  1.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.66it/s]
#                    all         29        162      0.362      0.686      0.539       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         4/9      6.83G      1.189      3.642      1.079          0        640: 100% 14/14 [00:10<00:00,  1.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.86it/s]
#                    all         29        162      0.601      0.694      0.614      0.394
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         5/9      6.83G      1.251      1.055       1.22          3        640: 100% 14/14 [00:11<00:00,  1.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.74it/s]
#                    all         29        162      0.596      0.673      0.681      0.457
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         6/9      7.57G      1.329      1.031      1.145         27        640: 100% 14/14 [00:10<00:00,  1.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.84it/s]
#                    all         29        162      0.816      0.585      0.767      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         7/9      7.57G      1.237     0.9721       1.18          3        640: 100% 14/14 [00:11<00:00,  1.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.62it/s]
#                    all         29        162       0.87      0.736      0.886      0.606
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         8/9      7.57G        1.2     0.8256      1.175         14        640: 100% 14/14 [00:10<00:00,  1.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.82it/s]
#                    all         29        162      0.826      0.826       0.89      0.589
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         9/9      7.57G      1.213     0.7971      1.146         25        640: 100% 14/14 [00:11<00:00,  1.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.87it/s]
#                    all         29        162      0.862      0.777      0.863      0.592
#
# 10 epochs completed in 0.041 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, saved as runs/train/exp/weights/last_striped.pt, 51.5MB
# Optimizer stripped from runs/train/exp/weights/best.pt, saved as runs/train/exp/weights/best_striped.pt, 51.5MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# gelan-c summary: 467 layers, 25412502 parameters, 0 gradients, 102.5 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:01<00:00,  1.56it/s]
#                    all         29        162      0.869      0.736      0.888      0.608
#                   mask         29        142      0.967      0.623      0.925      0.641
#                no-mask         29         20      0.771       0.85      0.851      0.576
# Results saved to runs/train/exp

# %% [markdown]
# ## Examine Training Results

# %% [markdown]
# **NOTE:** By default, the results of each subsequent training sessions are saved in `{HOME}/yolov9/runs/train/`, in directories named `exp`, `exp2`, `exp3`, ... You can override this behavior by using the `--name` parameter.

# %%
# !ls {HOME}/yolov9/runs/train/exp/
# Out:
# confusion_matrix.png				    P_curve.png       train_batch2.jpg
# events.out.tfevents.1709978334.02bdc6295e16.6026.0  PR_curve.png      val_batch0_labels.jpg
# F1_curve.png					    R_curve.png       val_batch0_pred.jpg
# hyp.yaml					    results.csv       val_batch1_labels.jpg
# labels_correlogram.jpg				    results.png       val_batch1_pred.jpg
# labels.jpg					    train_batch0.jpg  weights
# opt.yaml					    train_batch1.jpg

# %%
Image(filename=f"{HOME}/yolov9/runs/train/exp/results.png", width=1000)

# %%
Image(filename=f"{HOME}/yolov9/runs/train/exp/confusion_matrix.png", width=1000)

# %%
Image(filename=f"{HOME}/yolov9/runs/train/exp/val_batch0_pred.jpg", width=1000)

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}/yolov9

# !python val.py \
--img 640 --batch 8 --conf 0.001 --iou 0.7 --device 0 \
--data {dataset.location}/data.yaml \
--weights {HOME}/yolov9/runs/train/exp/weights/best.pt
# Out:
# /content/yolov9
# val: data=/content/yolov9/Mask-Wearing-4/data.yaml, weights=['/content/yolov9/runs/train/exp/weights/best.pt'], batch_size=8, imgsz=640, conf_thres=0.001, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False, min_items=0
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25412502 parameters, 0 gradients, 102.5 GFLOPs
# val: Scanning /content/yolov9/Mask-Wearing-4/valid/labels.cache... 29 images, 0 backgrounds, 0 corrupt: 100% 29/29 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 4/4 [00:05<00:00,  1.49s/it]
#                    all         29        162      0.869      0.739      0.888      0.607
#                   mask         29        142      0.967      0.628      0.925      0.641
#                no-mask         29         20      0.771       0.85      0.851      0.572
# Speed: 0.6ms pre-process, 128.4ms inference, 33.9ms NMS per image at shape (8, 3, 640, 640)
# Results saved to runs/val/exp

# %% [markdown]
# ## Inference with Custom Model

# %%
# !python detect.py \
--img 640 --conf 0.1 --device 0 \
--weights {HOME}/yolov9/runs/train/exp/weights/best.pt \
--source {dataset.location}/valid/images
# Out:
# detect: weights=['/content/yolov9/runs/train/exp/weights/best.pt'], source=/content/yolov9/Mask-Wearing-4/valid/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25412502 parameters, 0 gradients, 102.5 GFLOPs
# image 1/29 /content/yolov9/Mask-Wearing-4/valid/images/0009S6815V3PEU1N-C123-F4_jpg.rf.128ad940f96aa8fa5174093ddb7ae5ee.jpg: 480x640 4 masks, 4 no-masks, 127.7ms
# image 2/29 /content/yolov9/Mask-Wearing-4/valid/images/000_1OC3DT_jpg.rf.3d1fb8e38f21ec81247c6c3850038888.jpg: 448x640 13 masks, 2 no-masks, 103.0ms
# image 3/29 /content/yolov9/Mask-Wearing-4/valid/images/002_1024_jpeg.rf.21167ff8a675d17c91a8c57a5269dad7.jpg: 384x640 3 masks, 108.3ms
# image 4/29 /content/yolov9/Mask-Wearing-4/valid/images/0109-00176-096b1_jpg.rf.69ffdcd78617808a849bb59feea2afca.jpg: 640x416 1 mask, 101.1ms
# image 5/29 /content/yolov9/Mask-Wearing-4/valid/images/022814asiatodaymasks_960x540_jpg.rf.a334c489daa4a1db00e580a7a516ce66.jpg: 384x640 5 masks, 1 no-mask, 33.9ms
# image 6/29 /content/yolov9/Mask-Wearing-4/valid/images/025418_springwest005_jpg.rf.9342b3603f02ddb7d28ea4c91f711677.jpg: 448x640 8 masks, 7 no-masks, 39.6ms
# image 7/29 /content/yolov9/Mask-Wearing-4/valid/images/08165739_jpg.rf.81a9ba05554adbce15ed6cd7dfac96cf.jpg: 384x640 6 masks, 1 no-mask, 33.1ms
# image 8/29 /content/yolov9/Mask-Wearing-4/valid/images/08_11_2019-airpollution_234_19737819_192539446_jpg.rf.fa2a2fbe265356ca47e94944207ecbb5.jpg: 544x640 2 masks, 2 no-masks, 108.9ms
# image 9/29 /content/yolov9/Mask-Wearing-4/valid/images/0ad90195-cd77-489e-bf85-08c83b80d3e0_jpg.rf.006de569e2242cb425b5f931c5e0f8be.jpg: 384x640 3 masks, 8 no-masks, 31.3ms
# image 10/29 /content/yolov9/Mask-Wearing-4/valid/images/10fea_8011463765e2aa28b386cf_jpg.rf.7981dc5de795ab4252631683e0de84ae.jpg: 384x640 2 masks, 1 no-mask, 30.3ms
# image 11/29 /content/yolov9/Mask-Wearing-4/valid/images/1125506397_15801322206581n_jpg.rf.3c089d43976a3dd3b0dfab58bdcac999.jpg: 480x640 4 masks, 2 no-masks, 38.5ms
# image 12/29 /content/yolov9/Mask-Wearing-4/valid/images/1196686205_jpg_14_jpg.rf.95f742744c99ce310aea3fee820b6811.jpg: 448x640 4 masks, 28.5ms
# image 13/29 /content/yolov9/Mask-Wearing-4/valid/images/1197315184_jpg_0_jpg.rf.448838b1a29be91ef9c08cc895837686.jpg: 448x640 13 masks, 11 no-masks, 27.8ms
# image 14/29 /content/yolov9/Mask-Wearing-4/valid/images/1197620896_jpg.rf.b987b8c72404cdfd4c5d123e713326eb.jpg: 480x640 5 masks, 3 no-masks, 29.7ms
# image 15/29 /content/yolov9/Mask-Wearing-4/valid/images/1483800496-3386248642_jpg.rf.6a8d7d7f3c7ca1b7129c902610068440.jpg: 640x640 6 masks, 1 no-mask, 37.3ms
# image 16/29 /content/yolov9/Mask-Wearing-4/valid/images/15150794626913_jpg.rf.78b49f28af0f2654221ae46fb04eb549.jpg: 640x640 7 masks, 4 no-masks, 36.1ms
# image 17/29 /content/yolov9/Mask-Wearing-4/valid/images/15391513321824spp815on8_jpg.rf.cbea58f57f15ea6ee59970ad58b1cbf4.jpg: 640x448 2 masks, 2 no-masks, 97.8ms
# image 18/29 /content/yolov9/Mask-Wearing-4/valid/images/REVZGCBIJNQPMIIXOKDCQA3GJI_jpg.rf.f948274557822ca0e7764d95cd137c13.jpg: 416x640 8 masks, 1 no-mask, 104.7ms
# image 19/29 /content/yolov9/Mask-Wearing-4/valid/images/S1-EV360_FACEMA_M_20200130144349_jpg.rf.c6beae438ca764fe58afb2f3d747aca3.jpg: 448x640 22 masks, 9 no-masks, 27.0ms
# image 20/29 /content/yolov9/Mask-Wearing-4/valid/images/phpM5suKS_jpg.rf.6bfbc753f035295f8b61751be4ab9945.jpg: 608x640 3 masks, 4 no-masks, 109.2ms
# image 21/29 /content/yolov9/Mask-Wearing-4/valid/images/r1000019q669394n9qp_jpg.rf.4ea90092a57dfae9753bfdad3193ea2c.jpg: 640x448 1 mask, 25.7ms
# image 22/29 /content/yolov9/Mask-Wearing-4/valid/images/r1400018548960op29s_jpg.rf.1aa9ecf11eb6e101f0bbdf0c3048702c.jpg: 640x448 1 mask, 24.8ms
# image 23/29 /content/yolov9/Mask-Wearing-4/valid/images/sdgdsgsg_jpg.rf.2296809055f00546a3bb756a73bb4472.jpg: 640x640 4 masks, 35.4ms
# image 24/29 /content/yolov9/Mask-Wearing-4/valid/images/shutterstock_1145933543-e1579497052960_jpg.rf.484e9b9fdec9aa67a63d08df3958cba6.jpg: 512x640 1 mask, 103.0ms
# image 25/29 /content/yolov9/Mask-Wearing-4/valid/images/shutterstock_editorial_10536831j_2e16d0ba_fill-1200x650_jpg.rf.4b10ecf8292b69a042239f8d426feaab.jpg: 352x640 42 masks, 17 no-masks, 105.1ms
# image 26/29 /content/yolov9/Mask-Wearing-4/valid/images/stock-photo-mother-and-her-daughter-walking-go-to-school-with-wearing-a-protection-mask-against-pm-air-1346870465_jpg.rf.1af78a7aa3ada1688f46a406f51ba584.jpg: 640x416 2 masks, 24.6ms
# image 27/29 /content/yolov9/Mask-Wearing-4/valid/images/us-state-department-warns-against-visiting-china-citing-coronavirus_jpg.rf.51aea5bc06a6e1f9113bbed4a7068697.jpg: 448x640 5 masks, 5 no-masks, 25.3ms
# image 28/29 /content/yolov9/Mask-Wearing-4/valid/images/w1240-p16x9-CORONAVIRUS-CHINA-HEALTH-APPLE STORE_jpg.rf.69b0624b52841ca749dc6a289fba53df.jpg: 384x640 6 masks, 2 no-masks, 23.9ms
# image 29/29 /content/yolov9/Mask-Wearing-4/valid/images/w1240-p16x9-coronavirus_CHINA-HEALTH_jpg.rf.095ad216d07f4d521dbd956834f793ea.jpg: 384x640 4 masks, 27.9ms
# Speed: 0.6ms pre-process, 56.9ms inference, 22.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/yolov9/runs/detect/exp3/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")
